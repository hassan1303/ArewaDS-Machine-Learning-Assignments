# %%
# Visualizing Quantities

# %%
## Build a line plot about bird Snow Geese values

# %%
import pandas as pd
import matplotlib.pyplot as plt
birds = pd.read_csv('birds.csv')
birds.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# ...

# %%
plt.title('Min BodyMass in Centimeters')
plt.ylabel('BodyMass (CM)')
plt.xlabel('Birds')
body_mass = birds.MaxWingspan
body_mass.plot()
# Out:
# <AxesSubplot:title={'center':'Min BodyMass in Centimeters'}, xlabel='Birds', ylabel='BodyMass (CM)'>

# %%
# Show the birds' names correlated to their body mass

plt.title('Min BodyMass in Centimeters')
plt.ylabel('BodyMass (CM)')
plt.xlabel('Birds')
plt.xticks(rotation=45)
x = birds['Name']
y = birds['MinBodyMass']

plt.plot(x, y)

plt.show()

# %%
# Label the birds whose difference between max body mass and min body mass is equal to 100


plt.title('Max BodyMass in Centimeters')
plt.ylabel('BodyMass (CM)')
plt.tick_params(axis='both',which='both',labelbottom=False,bottom=False)

for i in range(len(birds)):
    x = birds['Name'][i]
    y = birds['MaxBodyMass'][i]
    plt.plot(x, y, 'bo')
    if (birds['MaxBodyMass'][i]-birds['MinBodyMass'][i]) == 2000:
        plt.text(x, y * (1 - 0.05), birds['Name'][i], fontsize=12)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# bar chart
birds.plot(x='Category',
        kind='bar',
        stacked=True,
        title='Birds of Minnesota')
# Out:
# <AxesSubplot:title={'center':'Birds of Minnesota'}, xlabel='Category'>

# %%
# draw bar chart by birds category
category_count = birds.value_counts(birds['Category'].values, sort=True)
plt.rcParams['figure.figsize'] = [6, 12]
category_count.plot.barh()
# Out:
# <AxesSubplot:>

# %%
minBodyMass = birds['MinBodyMass']
maxBodyMass = birds['MaxBodyMass']
category = birds['Category']

plt.barh(category, minBodyMass)
plt.barh(category, maxBodyMass)

plt.show()
